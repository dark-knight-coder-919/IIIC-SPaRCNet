# %%
import matplotlib as plt
import numpy as np
import pandas as pd
import plotly.express as px
import scipy.integrate as integrate
import plotly.graph_objects as go

# %%
def visualize_data(file_path, threshold, curve_type):
    # add an explicit “time” column to get 0,1,2,… on x-axis
    types = ['seizure', 'lpd', 'gpd', 'lrda', 'grda', 'other']
    df = pd.read_csv(file_path, header=None, names=types)
    df["time"] = df.index

    # line chart
    fig = px.line(
        df,
        x="time",
        y=types,  # list of your six event‐columns
        title="Event Probabilities Over Time"
    )

    fig.update_layout(
        yaxis_title="Probability",
    )

    # range‐slider under the x‐axis
    fig.update_xaxes(
        rangeslider_visible=True,
        title_text="Time (segment index)"
    )
    fig.add_hline(y=threshold)


    # integrate area under specific curve
    time = df.index.values
    y = df[curve_type].values
    excess = np.clip(y - threshold, a_min=0, a_max=None)

    area = np.trapezoid(excess, x=time)

    y = df[curve_type].values
    clipped = np.clip(y, a_min=threshold, a_max=None)

    fig.add_trace(
        go.Scatter(
            x=df['time'],
            y=[threshold]*len(df),
            mode='lines',
            line=dict(color='gray', width=1, dash='dash'),
            name=f"Threshold = {threshold}",
            showlegend=False   # don’t duplicate in legend
        )
    )

    # add a filling trace for the chosen curve
    fig.add_trace(
        go.Scatter(
            x=df['time'],
            y=clipped,
            mode='lines',
            line=dict(color='rgba(0,0,0,0)'),   # invisible line
            fill='tonexty',                      # fill to the previous y (the threshold trace)
            fillcolor='rgba(31,119,180,0.2)',    # semi‐transparent blue
            name=f"Area above {curve_type}",
            showlegend=False
        )
    )

    print(f"Integrated area above {threshold:.2f} is {area:.3f}")

    fig.show()
    return None

# %%
file_path = "C:\\Users\\nbarnouw\\PycharmProjects\\IIIC-SPaRCNet\\SPaRCNet\\Data\\iiic\\ecmo_200\\ecmo_200XK4J_001_20210122_030100_score.csv"

# file_path = "C:\\Users\\nbarnouw\\PycharmProjects\\IIIC-SPaRCNet\\SPaRCNet\\Data\\iiic\\sample_cEEG_score.csv"

print(visualize_data(file_path, 0.7, 'lpd'))
# Out:
# Integrated area above 0.70 is 26.628
# None

# %%
# in Data/iiic/ecmo_200/ecmo_200XK4J_001_20210122_030100_score.csv
# old, hard to see specific sections of data
# def visualize_data_old(file_path, threshold):
#     types = ['seizure', 'lpd', 'gpd', 'lrda', 'grda', 'other']
    # data = pd.read_csv(file_path, header=None, names=types)
    # data = data.iloc[0:100, :]
    # ax = data.plot(
        # figsize=(10, 5),
        # title="Event Probabilities Over Time",
        # xlabel="Time Segment Number",
        # ylabel="Probability of each event"
    # )
    # ax.axhline(threshold, linestyle="--", linewidth=1, label="Threshold = 0.3")
#
#     return None
